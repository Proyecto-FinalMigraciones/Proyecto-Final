# %% [markdown]
# # ETL

# %%
import pandas as pd

# %% [markdown]
# # DESTINO MUJERES

# %%
destino_mujeres = pd.read_csv('Proyecto-Final/Datasets/destino_mujeres.csv', skiprows = 10)
destino_mujeres
# Out:
#      Unnamed: 0 Region, development group, country or area  Notes  \
# 0             1                                      WORLD    NaN
# 1             2                         Sub-Saharan Africa    NaN
# 2             3           Northern Africa and Western Asia    NaN
# 3             4                  Central and Southern Asia    NaN
# 4             5             Eastern and South-Eastern Asia    NaN
# ..          ...                                        ...    ...
# 278         279                                      Samoa    NaN
# 279         280                                   Tokelau*   40.0
# 280         281                                      Tonga    NaN
# 281         282                                     Tuvalu    NaN
# 282         283                 Wallis and Futuna Islands*   41.0
#
#      Location code Type of data  1990  1995  2000  2005  2010  2015  2020
# 0              900          NaN  49.3  49.4  49.4  49.0  48.4  48.3  48.1
# ...

# %%
destino_mujeres.drop(['Unnamed: 0'], axis=1, inplace = True)
destino_mujeres
# Out:
#     Region, development group, country or area  Notes  Location code  \
# 0                                        WORLD    NaN            900
# 1                           Sub-Saharan Africa    NaN            947
# 2             Northern Africa and Western Asia    NaN           1833
# 3                    Central and Southern Asia    NaN            921
# 4               Eastern and South-Eastern Asia    NaN           1832
# ..                                         ...    ...            ...
# 278                                      Samoa    NaN            882
# 279                                   Tokelau*   40.0            772
# 280                                      Tonga    NaN            776
# 281                                     Tuvalu    NaN            798
# 282                 Wallis and Futuna Islands*   41.0            876
#
#     Type of data  1990  1995  2000  2005  2010  2015  2020
# 0            NaN  49.3  49.4  49.4  49.0  48.4  48.3  48.1
# ...

# %%
destino_mujeres.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 283 entries, 0 to 282
# Data columns (total 11 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Region, development group, country or area  283 non-null    object
#  1   Notes                                       40 non-null     float64
#  2   Location code                               283 non-null    int64
#  3   Type of data                                232 non-null    object
#  4   1990                                        283 non-null    object
#  5   1995                                        283 non-null    object
#  6   2000                                        283 non-null    object
#  7   2005                                        283 non-null    object
#  8   2010                                        283 non-null    object
#  9   2015                                        283 non-null    object
# ...

# %%
destino_mujeres['Type of data'] = destino_mujeres['Type of data'].fillna('0')

# %%
destino_mujeres.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 283 entries, 0 to 282
# Data columns (total 11 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Region, development group, country or area  283 non-null    object
#  1   Notes                                       40 non-null     float64
#  2   Location code                               283 non-null    int64
#  3   Type of data                                283 non-null    object
#  4   1990                                        283 non-null    object
#  5   1995                                        283 non-null    object
#  6   2000                                        283 non-null    object
#  7   2005                                        283 non-null    object
#  8   2010                                        283 non-null    object
#  9   2015                                        283 non-null    object
# ...

# %%
columnas = ['1990', '1995', '2000', '2005', '2010', '2015', '2020']

# %%
for col in columnas:
    destino_mujeres[col] = pd.to_numeric(destino_mujeres[col], errors='coerce').fillna(0)

# %%
destino_mujeres
# Out:
#     Region, development group, country or area  Notes  Location code  \
# 0                                        WORLD    NaN            900
# 1                           Sub-Saharan Africa    NaN            947
# 2             Northern Africa and Western Asia    NaN           1833
# 3                    Central and Southern Asia    NaN            921
# 4               Eastern and South-Eastern Asia    NaN           1832
# ..                                         ...    ...            ...
# 278                                      Samoa    NaN            882
# 279                                   Tokelau*   40.0            772
# 280                                      Tonga    NaN            776
# 281                                     Tuvalu    NaN            798
# 282                 Wallis and Futuna Islands*   41.0            876
#
#     Type of data  1990  1995  2000  2005  2010  2015  2020
# 0              0  49.3  49.4  49.4  49.0  48.4  48.3  48.1
# ...

# %%
destino_mujeres['Notes'] = destino_mujeres['Notes'].fillna('0')

# %%
destino_mujeres.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 283 entries, 0 to 282
# Data columns (total 11 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Region, development group, country or area  283 non-null    object
#  1   Notes                                       283 non-null    object
#  2   Location code                               283 non-null    int64
#  3   Type of data                                283 non-null    object
#  4   1990                                        283 non-null    float64
#  5   1995                                        283 non-null    float64
#  6   2000                                        283 non-null    float64
#  7   2005                                        283 non-null    float64
#  8   2010                                        283 non-null    float64
# ...

# %%
year_columns = destino_mujeres.columns[4:]

destino_mujeres = pd.melt(destino_mujeres, id_vars=destino_mujeres.columns[:4], value_vars=year_columns, var_name='Year', value_name='Numero de Migrantes')

# %%
destino_mujeres
# Out:
#      Region, development group, country or area Notes  Location code  \
# 0                                         WORLD     0            900
# 1                            Sub-Saharan Africa     0            947
# 2              Northern Africa and Western Asia     0           1833
# 3                     Central and Southern Asia     0            921
# 4                Eastern and South-Eastern Asia     0           1832
# ...                                         ...   ...            ...
# 1976                                      Samoa     0            882
# 1977                                   Tokelau*  40.0            772
# 1978                                      Tonga     0            776
# 1979                                     Tuvalu     0            798
# 1980                 Wallis and Futuna Islands*  41.0            876
#
#      Type of data  Year  Numero de Migrantes
# 0               0  1990                 49.3
# 1               0  1990                 46.9
# ...

# %%
valores_unicos = destino_mujeres['Region, development group, country or area'].unique()
print(valores_unicos)
# Out:
# ['WORLD' '  Sub-Saharan Africa' '  Northern Africa and Western Asia'
#  '  Central and Southern Asia' '  Eastern and South-Eastern Asia'
#  '  Latin America and the Caribbean'
#  '  Oceania (excluding Australia and New Zealand)'
#  '  Australia and New Zealand' '  Europe and Northern America'
#  '  Developed regions' '  Less developed regions'
#  ' Less developed regions, excluding least developed countries'
#  ' Less developed regions, excluding China' '  Least developed countries'
#  '  Land-locked Developing Countries (LLDC)'
#  '  Small island developing States (SIDS)' '  High-income countries'
#  '  Middle-income countries' ' Upper-middle-income countries'
#  ' Lower-middle-income countries' '  Low-income countries' ' AFRICA'
#  '  Eastern Africa' '   Burundi' '   Comoros' '   Djibouti' '   Eritrea'
#  '   Ethiopia' '   Kenya' '   Madagascar' '   Malawi' '   Mauritius*'
#  '   Mayotte*' '   Mozambique' '   Réunion*' '   Rwanda' '   Seychelles'
# ...

# %%
valores_a_eliminar = ['WORLD', 'Sub-Saharan Africa', 'Northern Africa and Western Asia',
                     'Central and Southern Asia', 'Eastern and South-Eastern Asia',
                     'Latin America and the Caribbean',
                     'Oceania (excluding Australia and New Zealand)',
                     'Australia and New Zealand', 'Europe and Northern America',
                     'Developed regions', 'Less developed regions',
                     'Less developed regions, excluding least developed countries',
                     'Less developed regions, excluding China',
                     'Least developed countries',
                     'Land-locked Developing Countries (LLDC)',
                     'Small island developing States (SIDS)',
                     'High-income countries', 'Middle-income countries',
                     'Upper-middle-income countries', 'Lower-middle-income countries',
                     'Low-income countries', 'AFRICA', 'Eastern Africa']

# %%
destino_mujeres_pais = destino_mujeres[~destino_mujeres['Region, development group, country or area'].str.strip().isin(valores_a_eliminar)].copy()
destino_mujeres_pais
# Out:
#      Region, development group, country or area Notes  Location code  \
# 23                                      Burundi     0            108
# 24                                      Comoros     0            174
# 25                                     Djibouti     0            262
# 26                                      Eritrea     0            232
# 27                                     Ethiopia     0            231
# ...                                         ...   ...            ...
# 1976                                      Samoa     0            882
# 1977                                   Tokelau*  40.0            772
# 1978                                      Tonga     0            776
# 1979                                     Tuvalu     0            798
# 1980                 Wallis and Futuna Islands*  41.0            876
#
#      Type of data  Year  Numero de Migrantes
# 23            B R  1990                 51.0
# 24              B  1990                 52.3
# ...

# %%
destino_mujeres_region =  destino_mujeres.head(23).copy()

# %%
destino_mujeres_region
# Out:
#            Region, development group, country or area Notes  Location code  \
# 0                                               WORLD     0            900
# 1                                  Sub-Saharan Africa     0            947
# 2                    Northern Africa and Western Asia     0           1833
# 3                           Central and Southern Asia     0            921
# 4                      Eastern and South-Eastern Asia     0           1832
# 5                     Latin America and the Caribbean     0           1830
# 6       Oceania (excluding Australia and New Zealand)     0           1835
# 7                           Australia and New Zealand     0            927
# 8                         Europe and Northern America     0           1829
# 9                                   Developed regions     0            901
# 10                             Less developed regions     0            902
# ...

# %%
destino_mujeres
# Out:
#      Region, development group, country or area Notes  Location code  \
# 0                                         WORLD     0            900
# 1                            Sub-Saharan Africa     0            947
# 2              Northern Africa and Western Asia     0           1833
# 3                     Central and Southern Asia     0            921
# 4                Eastern and South-Eastern Asia     0           1832
# ...                                         ...   ...            ...
# 1976                                      Samoa     0            882
# 1977                                   Tokelau*  40.0            772
# 1978                                      Tonga     0            776
# 1979                                     Tuvalu     0            798
# 1980                 Wallis and Futuna Islands*  41.0            876
#
#      Type of data  Year  Numero de Migrantes
# 0               0  1990                 49.3
# 1               0  1990                 46.9
# ...

# %%
destino_mujeres_pais.to_csv('destino_mujeres_pais.csv', index = False)

# %%
destino_mujeres_region.to_csv('destino_mujeres_region.csv', index = False)

# %% [markdown]
# # DESTINO PORCENTAJE

# %%
destino_porcentaje = pd.read_csv('Proyecto-Final/Datasets/destino_porcentaje.csv', skiprows = 10)
destino_porcentaje
# Out:
#      Unnamed: 0 Region, development group, country or area  Notes  \
# 0             1                                      WORLD    NaN
# 1             2                         Sub-Saharan Africa    NaN
# 2             3           Northern Africa and Western Asia    NaN
# 3             4                  Central and Southern Asia    NaN
# 4             5             Eastern and South-Eastern Asia    NaN
# ..          ...                                        ...    ...
# 278         279                                      Samoa    NaN
# 279         280                                   Tokelau*   40.0
# 280         281                                      Tonga    NaN
# 281         282                                     Tuvalu    NaN
# 282         283                 Wallis and Futuna Islands*   41.0
#
#      Location code Type of data  1990  1995  2000  2005  2010  ... 2010.1  \
# 0              900          NaN   2.9   2.8   2.8   2.9   3.2  ...    3.2
# ...

# %%
destino_porcentaje.drop(['Unnamed: 0'], axis=1, inplace = True)
destino_porcentaje
# Out:
#     Region, development group, country or area  Notes  Location code  \
# 0                                        WORLD    NaN            900
# 1                           Sub-Saharan Africa    NaN            947
# 2             Northern Africa and Western Asia    NaN           1833
# 3                    Central and Southern Asia    NaN            921
# 4               Eastern and South-Eastern Asia    NaN           1832
# ..                                         ...    ...            ...
# 278                                      Samoa    NaN            882
# 279                                   Tokelau*   40.0            772
# 280                                      Tonga    NaN            776
# 281                                     Tuvalu    NaN            798
# 282                 Wallis and Futuna Islands*   41.0            876
#
#     Type of data  1990  1995  2000  2005  2010  2015  ... 2010.1 2015.1  \
# ...

# %%
destino_porcentaje.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 283 entries, 0 to 282
# Data columns (total 25 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Region, development group, country or area  283 non-null    object
#  1   Notes                                       40 non-null     float64
#  2   Location code                               283 non-null    int64
#  3   Type of data                                232 non-null    object
#  4   1990                                        283 non-null    object
#  5   1995                                        283 non-null    object
#  6   2000                                        283 non-null    object
#  7   2005                                        283 non-null    object
#  8   2010                                        283 non-null    object
#  9   2015                                        283 non-null    object
# ...

# %%
destino_porcentaje[['1990', '1990.1', '1990.2']]
# Out:
#      1990 1990.1 1990.2
# 0     2.9    2.9    2.9
# 1     2.7    2.9    2.5
# 2     6.1    7.0    5.2
# 3     2.1    2.1    2.2
# 4     0.4    0.4    0.4
# ..    ...    ...    ...
# 278   2.1    2.1    2.0
# 279  22.4     ..     ..
# 280   3.1    3.1    3.0
# 281   3.6     ..     ..
# 282  10.2     ..     ..
#
# [283 rows x 3 columns]

# %%
destino_porcentaje['Notes'] = destino_porcentaje['Notes'].fillna('0')

# %%
destino_porcentaje['Type of data'] = destino_porcentaje['Type of data'].fillna('0')
destino_porcentaje.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 283 entries, 0 to 282
# Data columns (total 25 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Region, development group, country or area  283 non-null    object
#  1   Notes                                       283 non-null    object
#  2   Location code                               283 non-null    int64
#  3   Type of data                                283 non-null    object
#  4   1990                                        283 non-null    object
#  5   1995                                        283 non-null    object
#  6   2000                                        283 non-null    object
#  7   2005                                        283 non-null    object
#  8   2010                                        283 non-null    object
#  9   2015                                        283 non-null    object
# ...

# %%
columnas = ['1990', '1995', '2000', '2005', '2010', '2015', '2020', '1990.1', '1995.1', '2000.1', '2005.1', '2010.1', '2015.1', '2020.1', '1990.2', '1995.2', '2000.2', '2005.2', '2010.2', '2015.2', '2020.2']

# %%
for col in columnas:
    destino_porcentaje[col] = pd.to_numeric(destino_porcentaje[col], errors='coerce').fillna(0)

# %%
destino_porcentaje.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 283 entries, 0 to 282
# Data columns (total 25 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Region, development group, country or area  283 non-null    object
#  1   Notes                                       283 non-null    object
#  2   Location code                               283 non-null    int64
#  3   Type of data                                283 non-null    object
#  4   1990                                        283 non-null    float64
#  5   1995                                        283 non-null    float64
#  6   2000                                        283 non-null    float64
#  7   2005                                        283 non-null    float64
#  8   2010                                        283 non-null    float64
# ...

# %%
(destino_porcentaje['1990'] == 0).sum()
# Out:
# 9

# %%
columnas_excluidas = ['Region, development group, country or area', 'Notes', 'Location code', 'Type of data']

# %%
for col in destino_porcentaje.columns:
    if col not in columnas_excluidas:
        if col.endswith('.1'):
            new_col = col.replace('.1', 'H')
        elif col.endswith('.2'):
            new_col = col.replace('.2', 'M')
        else:
            new_col = col + 'C'
        destino_porcentaje.rename(columns={col: new_col}, inplace=True)

# %%
destino_porcentaje
# Out:
#     Region, development group, country or area Notes  Location code  \
# 0                                        WORLD     0            900
# 1                           Sub-Saharan Africa     0            947
# 2             Northern Africa and Western Asia     0           1833
# 3                    Central and Southern Asia     0            921
# 4               Eastern and South-Eastern Asia     0           1832
# ..                                         ...   ...            ...
# 278                                      Samoa     0            882
# 279                                   Tokelau*  40.0            772
# 280                                      Tonga     0            776
# 281                                     Tuvalu     0            798
# 282                 Wallis and Futuna Islands*  41.0            876
#
#     Type of data  1990C  1995C  2000C  2005C  2010C  2015C  ...  2010H  2015H  \
# ...

# %%
valores_unicosp = destino_porcentaje['Region, development group, country or area'].unique()
print(valores_unicosp)
# Out:
# ['WORLD' '  Sub-Saharan Africa' '  Northern Africa and Western Asia'
#  '  Central and Southern Asia' '  Eastern and South-Eastern Asia'
#  '  Latin America and the Caribbean'
#  '  Oceania (excluding Australia and New Zealand)'
#  '  Australia and New Zealand' '  Europe and Northern America'
#  '  Developed regions' '  Less developed regions'
#  ' Less developed regions, excluding least developed countries'
#  ' Less developed regions, excluding China' '  Least developed countries'
#  '  Land-locked Developing Countries (LLDC)'
#  '  Small island developing States (SIDS)' '  High-income countries'
#  '  Middle-income countries' ' Upper-middle-income countries'
#  ' Lower-middle-income countries' '  Low-income countries' ' AFRICA'
#  '  Eastern Africa' '   Burundi' '   Comoros' '   Djibouti' '   Eritrea'
#  '   Ethiopia' '   Kenya' '   Madagascar' '   Malawi' '   Mauritius*'
#  '   Mayotte*' '   Mozambique' '   Réunion*' '   Rwanda' '   Seychelles'
# ...

# %%
destino_porcentaje_pais = destino_porcentaje[~destino_porcentaje['Region, development group, country or area'].str.strip().isin(valores_a_eliminar)].copy()
destino_porcentaje_pais
# Out:
#     Region, development group, country or area Notes  Location code  \
# 23                                     Burundi     0            108
# 24                                     Comoros     0            174
# 25                                    Djibouti     0            262
# 26                                     Eritrea     0            232
# 27                                    Ethiopia     0            231
# ..                                         ...   ...            ...
# 278                                      Samoa     0            882
# 279                                   Tokelau*  40.0            772
# 280                                      Tonga     0            776
# 281                                     Tuvalu     0            798
# 282                 Wallis and Futuna Islands*  41.0            876
#
#     Type of data  1990C  1995C  2000C  2005C  2010C  2015C  ...  2010H  2015H  \
# ...

# %%
destino_porcentaje_region =  destino_porcentaje.head(23).copy()
destino_porcentaje_region
# Out:
#            Region, development group, country or area Notes  Location code  \
# 0                                               WORLD     0            900
# 1                                  Sub-Saharan Africa     0            947
# 2                    Northern Africa and Western Asia     0           1833
# 3                           Central and Southern Asia     0            921
# 4                      Eastern and South-Eastern Asia     0           1832
# 5                     Latin America and the Caribbean     0           1830
# 6       Oceania (excluding Australia and New Zealand)     0           1835
# 7                           Australia and New Zealand     0            927
# 8                         Europe and Northern America     0           1829
# 9                                   Developed regions     0            901
# 10                             Less developed regions     0            902
# ...

# %%
year_columns = destino_porcentaje_pais.columns[4:]

destino_porcentaje_pais = pd.melt(destino_porcentaje_pais, id_vars=destino_porcentaje_pais.columns[:4], value_vars=year_columns, var_name='Year', value_name='Numero de Migrantes')

# %%
destino_porcentaje_pais['Género'] = destino_porcentaje_pais['Year'].apply(lambda x: 'Hombres' if x.endswith('H') else ('Mujeres' if x.endswith('M') else 'Combinado'))

# %%
destino_porcentaje_pais
# Out:
#      Region, development group, country or area Notes  Location code  \
# 0                                       Burundi     0            108
# 1                                       Comoros     0            174
# 2                                      Djibouti     0            262
# 3                                       Eritrea     0            232
# 4                                      Ethiopia     0            231
# ...                                         ...   ...            ...
# 5434                                      Samoa     0            882
# 5435                                   Tokelau*  40.0            772
# 5436                                      Tonga     0            776
# 5437                                     Tuvalu     0            798
# 5438                 Wallis and Futuna Islands*  41.0            876
#
#      Type of data   Year  Numero de Migrantes     Género
# 0             B R  1990C                  6.1  Combinado
# ...

# %%
year_columns = destino_porcentaje_region.columns[4:]

destino_porcentaje_region = pd.melt(destino_porcentaje_region, id_vars=destino_porcentaje_region.columns[:4], value_vars=year_columns, var_name='Year', value_name='Numero de Migrantes')

# %%
destino_porcentaje_region['Género'] = destino_porcentaje_region['Year'].apply(lambda x: 'Hombres' if x.endswith('H') else ('Mujeres' if x.endswith('M') else 'Combinado'))

# %%
destino_porcentaje_region
# Out:
#     Region, development group, country or area Notes  Location code  \
# 0                                        WORLD     0            900
# 1                           Sub-Saharan Africa     0            947
# 2             Northern Africa and Western Asia     0           1833
# 3                    Central and Southern Asia     0            921
# 4               Eastern and South-Eastern Asia     0           1832
# ..                                         ...   ...            ...
# 478              Upper-middle-income countries     0           1502
# 479              Lower-middle-income countries     0           1501
# 480                       Low-income countries     0           1500
# 481                                     AFRICA     0            903
# 482                             Eastern Africa     0            910
#
#     Type of data   Year  Numero de Migrantes     Género
# 0              0  1990C                  2.9  Combinado
# ...

# %%
destino_porcentaje
# Out:
#      Region, development group, country or area Notes  Location code  \
# 0                                         WORLD     0            900
# 1                            Sub-Saharan Africa     0            947
# 2              Northern Africa and Western Asia     0           1833
# 3                     Central and Southern Asia     0            921
# 4                Eastern and South-Eastern Asia     0           1832
# ...                                         ...   ...            ...
# 5938                                      Samoa     0            882
# 5939                                   Tokelau*  40.0            772
# 5940                                      Tonga     0            776
# 5941                                     Tuvalu     0            798
# 5942                 Wallis and Futuna Islands*  41.0            876
#
#      Type of data   Year  Numero de Migrantes     Género
# 0               0  1990C                  2.9  Combinado
# ...

# %%
destino_porcentaje_pais.to_csv('destino_porcentaje_pais.csv', index = False)

# %%
destino_porcentaje_region.to_csv('destino_porcentaje_region.csv', index = False)
